# %% [markdown]
# # 1. 환경 설정

# %%
import pandas as pd
from pathlib import Path

# %%
def setup_data():
    org_path = "C:/Users/Owner/Desktop/지윤/3.기타/프로젝트/Ecommerce-Data-Exploration/"
    raw_path = f"{org_path}data/raw/"
    prc_path = f"{org_path}data/processed/"
    seed = 42

    print("변수 세팅 완료")
    return org_path, raw_path, prc_path, seed

# 사용 예시 (반환값 9개)
org_path, raw_path, prc_path, seed = setup_data()
# Out:
# 변수 세팅 완료

# %% [markdown]
# # 2. 테이블 로드

# %%
def load_multiple_csv(base_path: str, filenames: list[str]) -> dict[str, pd.DataFrame]:
    """
    여러 CSV 파일을 한 번에 불러와 DataFrame 딕셔너리로 반환합니다.
    
    Parameters
    ----------
    base_path : str
        기본 경로 (예: "data/raw/")
    filenames : list[str]
        확장자를 제외한 파일명 리스트 (예: ["orders", "products", "users"])

    Returns
    -------
    dict[str, pd.DataFrame]
        각 파일명을 key, DataFrame을 value로 하는 딕셔너리
    """
    base = Path(base_path)
    dataframes = {}

    for name in filenames:
        file_path = base / f"{name}.csv"
        if not file_path.exists():
            print(f"파일 없음: {file_path}")
            continue
        df = pd.read_csv(file_path)
        dataframes[name] = df
        print(f"{name}.csv 로드 완료. shape={df.shape}")

    return dataframes

# %%
file_list = [
    "distribution_centers", "events", "inventory_items",
    "order_items", "orders", "products", "users"
]

# CSV 로드
dfs = load_multiple_csv(raw_path, file_list)
# Out:
# distribution_centers.csv 로드 완료. shape=(10, 4)
# events.csv 로드 완료. shape=(2431963, 13)
# inventory_items.csv 로드 완료. shape=(490705, 12)
# order_items.csv 로드 완료. shape=(181759, 11)
# orders.csv 로드 완료. shape=(125226, 9)
# products.csv 로드 완료. shape=(29120, 9)
# users.csv 로드 완료. shape=(100000, 15)

# %%
# 변수 자동 생성
for name, df in dfs.items():
    globals()[name] = df
    print(f"변수 생성 완료: {name} (shape={df.shape})")
# Out:
# 변수 생성 완료: distribution_centers (shape=(10, 4))
# 변수 생성 완료: events (shape=(2431963, 13))
# 변수 생성 완료: inventory_items (shape=(490705, 12))
# 변수 생성 완료: order_items (shape=(181759, 11))
# 변수 생성 완료: orders (shape=(125226, 9))
# 변수 생성 완료: products (shape=(29120, 9))
# 변수 생성 완료: users (shape=(100000, 15))

# %% [markdown]
# # 3. 테이블별 요약 정보 확인

# %% [markdown]
# ## 3.1 distribution_centers

# %%
distribution_centers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         10 non-null     int64
#  1   name       10 non-null     object
#  2   latitude   10 non-null     float64
#  3   longitude  10 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
distribution_centers.describe(include='all')
# Out:
#               id        name   latitude   longitude
# count   10.00000          10  10.000000   10.000000
# unique       NaN          10        NaN         NaN
# top          NaN  Memphis TN        NaN         NaN
# freq         NaN           1        NaN         NaN
# mean     5.50000         NaN  34.679310  -87.938550
# std      3.02765         NaN   4.572666   12.722916
# min      1.00000         NaN  29.760400 -118.250000
# 25%      3.25000         NaN  31.024975  -90.042800
# 50%      5.50000         NaN  33.416650  -87.863900
# 75%      7.75000         NaN  38.741850  -80.229150
# max     10.00000         NaN  41.836900  -73.783400

# %%
distribution_centers
# Out:
#    id                                         name  latitude  longitude
# 0   1                                   Memphis TN   35.1174   -89.9711
# 1   2                                   Chicago IL   41.8369   -87.6847
# 2   3                                   Houston TX   29.7604   -95.3698
# 3   4                               Los Angeles CA   34.0500  -118.2500
# 4   5                               New Orleans LA   29.9500   -90.0667
# 5   6  Port Authority of New York/New Jersey NY/NJ   40.6340   -73.7834
# 6   7                              Philadelphia PA   39.9500   -75.1667
# 7   8                                    Mobile AL   30.6944   -88.0431
# 8   9                                Charleston SC   32.7833   -79.9333
# 9  10                                  Savannah GA   32.0167   -81.1167

# %% [markdown]
# ## 3.1 events

# %%
events.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2431963 entries, 0 to 2431962
# Data columns (total 13 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   id               2431963 non-null  int64
#  1   user_id          1306292 non-null  float64
#  2   sequence_number  2431963 non-null  int64
#  3   session_id       2431963 non-null  object
#  4   created_at       2431963 non-null  object
#  5   ip_address       2431963 non-null  object
#  6   city             2408883 non-null  object
#  7   state            2431963 non-null  object
#  8   postal_code      2431963 non-null  object
#  9   browser          2431963 non-null  object
#  10  traffic_source   2431963 non-null  object
#  11  uri              2431963 non-null  object
#  12  event_type       2431963 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 241.2+ MB

# %%
events.describe(include='all')
# Out:
#                   id       user_id  sequence_number  \
# count   2.431963e+06  1.306292e+06     2.431963e+06
# unique           NaN           NaN              NaN
# top              NaN           NaN              NaN
# freq             NaN           NaN              NaN
# mean    1.215982e+06  4.996636e+04     3.316146e+00
# std     7.020474e+05  2.881711e+04     2.676365e+00
# min     1.000000e+00  1.000000e+00     1.000000e+00
# 25%     6.079915e+05  2.500500e+04     1.000000e+00
# 50%     1.215982e+06  4.992700e+04     2.000000e+00
# 75%     1.823972e+06  7.483900e+04     4.000000e+00
# max     2.431963e+06  1.000000e+05     1.300000e+01
#
#                                   session_id                 created_at  \
# count                                2431963                    2431963
# unique                                681759                    2143390
# top     e846b988-9b63-4997-8a85-a4b81318ad0f  2021-10-27 03:05:00+00:00
# freq                                      13                          8
# mean                                     NaN                        NaN
# std                                      NaN                        NaN
# min                                      NaN                        NaN
# 25%                                      NaN                        NaN
# 50%                                      NaN                        NaN
# 75%                                      NaN                        NaN
# max                                      NaN                        NaN
#
#             ip_address      city      state postal_code  browser  \
# count          2431963   2408883    2431963     2431963  2431963
# unique          681683      8775        231       17324        5
# top     196.46.153.171  Shanghai  Guangdong   02675-031   Chrome
# freq                17     60561     129796       10147  1218687
# mean               NaN       NaN        NaN         NaN      NaN
# std                NaN       NaN        NaN         NaN      NaN
# min                NaN       NaN        NaN         NaN      NaN
# 25%                NaN       NaN        NaN         NaN      NaN
# 50%                NaN       NaN        NaN         NaN      NaN
# 75%                NaN       NaN        NaN         NaN      NaN
# max                NaN       NaN        NaN         NaN      NaN
#
#        traffic_source      uri event_type
# count         2431963  2431963    2431963
# unique              5    35530          6
# top             Email    /cart    product
# freq          1091988   595994     845607
# mean              NaN      NaN        NaN
# std               NaN      NaN        NaN
# min               NaN      NaN        NaN
# 25%               NaN      NaN        NaN
# 50%               NaN      NaN        NaN
# 75%               NaN      NaN        NaN
# max               NaN      NaN        NaN

# %%
events
# Out:
#               id  user_id  sequence_number  \
# 0        2198523      NaN                3
# 1        1773216      NaN                3
# 2        2380515      NaN                3
# 3        2250597      NaN                3
# 4        1834446      NaN                3
# ...          ...      ...              ...
# 2431958   822590  62906.0                5
# 2431959    43178   3333.0                5
# 2431960   553230  42386.0               10
# 2431961  1015190  77546.0                5
# 2431962   844526  64551.0               13
#
#                                    session_id                 created_at  \
# 0        83889ed2-2adc-4b9a-af5d-154f6998e778  2021-06-17 17:30:00+00:00
# 1        7a3fc3f2-e84f-44fe-8876-eff76741f7a3  2020-08-07 08:41:00+00:00
# 2        13d9b2fb-eee1-43fd-965c-267b38dd7125  2021-02-15 18:48:00+00:00
# 3        96f1d44e-9621-463c-954c-d8deb7fffe7f  2022-03-30 10:56:00+00:00
# 4        d09dce10-a7cb-47d3-a9af-44975566fa03  2019-09-05 01:18:00+00:00
# ...                                       ...                        ...
# 2431958  12ae51e7-76b3-4560-9335-3ea762eae60e  2022-04-07 01:55:02+00:00
# 2431959  e472549e-273e-402e-ae5f-38ece25699c2  2023-09-26 10:25:28+00:00
# 2431960  6a7ba027-2af2-46a3-ae05-294a264840cf  2023-07-31 15:11:10+00:00
# 2431961  29e5960c-214b-456e-8c38-fe6eb8ff1ec8  2024-01-02 14:26:38+00:00
# 2431962  9f633088-d2a8-4db2-8a5e-ebd946abce26  2022-09-15 09:55:32+00:00
#
#               ip_address           city      state postal_code  browser  \
# 0          138.143.9.202      São Paulo  São Paulo   02675-031   Chrome
# 1          85.114.141.79   Santa Isabel  São Paulo   07500-000   Safari
# 2        169.250.255.132      Mairiporã  São Paulo   07600-000       IE
# 3         137.25.222.160        Cajamar  São Paulo   07750-000   Chrome
# 4          161.114.4.174      São Paulo  São Paulo   09581-680   Chrome
# ...                  ...            ...        ...         ...      ...
# 2431958      52.92.60.25      St Helens    England         WA9  Firefox
# 2431959    97.78.106.249         Orrell    England         WN5       IE
# 2431960   147.252.137.75         Orrell    England         WN5   Chrome
# 2431961   112.209.120.82  Wolverhampton    England         WV6   Chrome
# 2431962  190.227.140.196           York    England        YO10  Firefox
#
#         traffic_source        uri event_type
# 0              Adwords    /cancel     cancel
# 1              Adwords    /cancel     cancel
# 2              Adwords    /cancel     cancel
# 3              Adwords    /cancel     cancel
# 4                Email    /cancel     cancel
# ...                ...        ...        ...
# 2431958        Adwords  /purchase   purchase
# 2431959          Email  /purchase   purchase
# 2431960       Facebook  /purchase   purchase
# 2431961        Adwords  /purchase   purchase
# 2431962          Email  /purchase   purchase
#
# [2431963 rows x 13 columns]

# %%
events['sequence_number'].value_counts()
# Out:
# sequence_number
# 1     681759
# 2     557043
# 3     432146
# 5     181759
# 4     181759
# 7      94047
# 6      94047
# 9      44313
# 10     44313
# 8      44313
# 12     25488
# 11     25488
# 13     25488
# Name: count, dtype: int64

# %%
# 같은 세션에서 여러 활동을 할 경우 sequence_number가 쌓이는 군
events.loc[events['sequence_number'] == 13, 'session_id'].value_counts().nunique()
# Out:
# 1

# %%
events.loc[events['sequence_number'] == 13, 'session_id'].head(1)
# Out:
# 23067    1daacb69-a4b6-4ef6-8686-bc62f86e87d5
# Name: session_id, dtype: object

# %%
session_value = events.loc[events["sequence_number"] == 13, "session_id"].iloc[0]
session_value
# Out:
# '1daacb69-a4b6-4ef6-8686-bc62f86e87d5'

# %%
events[events['session_id'] == session_value].sort_values('sequence_number')
# Out:
#              id  user_id  sequence_number  \
# 180935   808402  61899.0                1
# 1380212  808403  61899.0                2
# 920435   808404  61899.0                3
# 1323681  808405  61899.0                4
# 2396690  808406  61899.0                5
# 2309357  808407  61899.0                6
# 454229   808408  61899.0                7
# 1603433  808409  61899.0                8
# 1788944  808410  61899.0                9
# 354536   808411  61899.0               10
# 14423    808412  61899.0               11
# 1764160  808413  61899.0               12
# 23067    808414  61899.0               13
#
#                                    session_id                 created_at  \
# 180935   1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:20:40+00:00
# 1380212  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:20:46+00:00
# 920435   1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:21:07+00:00
# 1323681  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:21:40+00:00
# 2396690  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:22:25+00:00
# 2309357  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:23:29+00:00
# 454229   1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:24:47+00:00
# 1603433  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:25:08+00:00
# 1788944  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:27:12+00:00
# 354536   1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:28:39+00:00
# 14423    1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:30:55+00:00
# 1764160  1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-22 01:32:36+00:00
# 23067    1daacb69-a4b6-4ef6-8686-bc62f86e87d5  2023-02-25 01:33:38+00:00
#
#              ip_address       city      state postal_code browser  \
# 180935   191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 1380212  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 920435   191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 1323681  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 2396690  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 2309357  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 454229   191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 1603433  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 1788944  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 354536   191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 14423    191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 1764160  191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
# 23067    191.109.103.15  São Paulo  São Paulo   02220-000  Chrome
#
#         traffic_source                                                uri  \
# 180935        Facebook  /department/women/category/intimates/brand/sex...
# 1380212       Facebook                                     /product/12495
# 920435        Facebook                                              /cart
# 1323681       Facebook  /department/women/category/intimates/brand/sex...
# 2396690       Facebook                                     /product/12495
# 2309357       Facebook                                              /cart
# 454229        Facebook  /department/women/category/intimates/brand/sex...
# 1603433       Facebook                                     /product/12495
# 1788944       Facebook                                              /cart
# 354536        Facebook  /department/women/category/intimates/brand/sex...
# 14423         Facebook                                     /product/12495
# 1764160       Facebook                                              /cart
# 23067         Facebook                                          /purchase
#
#          event_type
# 180935   department
# 1380212     product
# 920435         cart
# 1323681  department
# 2396690     product
# 2309357        cart
# 454229   department
# 1603433     product
# 1788944        cart
# 354536   department
# 14423       product
# 1764160        cart
# 23067      purchase

# %%
events.groupby('user_id').apply(lambda x: x['session_id'].nunique()).sort_values(ascending=False).head(10)
#[['user_id', 'session_id']]
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_11196\147712173.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   events.groupby('user_id').apply(lambda x: x['session_id'].nunique()).sort_values(ascending=False).head(10)
# user_id
# 32996.0    14
# 80546.0    13
# 80952.0    13
# 40896.0    12
# 19415.0    12
# 57419.0    12
# 21909.0    12
# 96772.0    12
# 52039.0    12
# 33086.0    12
# dtype: int64

# %%
events[events['user_id'] == 32996.0].sort_values(['session_id', 'sequence_number'])
# Out:
#              id  user_id  sequence_number  \
# 778613   430495  32996.0                1
# 861029   430496  32996.0                2
# 1988645  430497  32996.0                3
# 1522982  430498  32996.0                4
# 1108932  430499  32996.0                5
# ...         ...      ...              ...
# 1393079  430543  32996.0                6
# 1696645  430544  32996.0                7
# 1505673  430545  32996.0                8
# 126515   430546  32996.0                9
# 1066760  430547  32996.0               10
#
#                                    session_id                 created_at  \
# 778613   091aec30-d8f4-497a-b825-9f35dd1673da  2024-01-11 12:55:07+00:00
# 861029   091aec30-d8f4-497a-b825-9f35dd1673da  2024-01-11 12:57:55+00:00
# 1988645  091aec30-d8f4-497a-b825-9f35dd1673da  2024-01-11 13:00:19+00:00
# 1522982  091aec30-d8f4-497a-b825-9f35dd1673da  2024-01-11 13:03:10+00:00
# 1108932  091aec30-d8f4-497a-b825-9f35dd1673da  2024-01-11 13:06:08+00:00
# ...                                       ...                        ...
# 1393079  f974f422-78fa-4fbb-bc1b-886b9720410c  2024-01-09 12:47:36+00:00
# 1696645  f974f422-78fa-4fbb-bc1b-886b9720410c  2024-01-09 12:50:35+00:00
# 1505673  f974f422-78fa-4fbb-bc1b-886b9720410c  2024-01-09 12:52:16+00:00
# 126515   f974f422-78fa-4fbb-bc1b-886b9720410c  2024-01-09 12:53:29+00:00
# 1066760  f974f422-78fa-4fbb-bc1b-886b9720410c  2024-01-13 12:54:30+00:00
#
#              ip_address     city    state postal_code browser traffic_source  \
# 778613     110.18.135.0  Hamburg  Hamburg       22587  Chrome       Facebook
# 861029     110.18.135.0  Hamburg  Hamburg       22587  Chrome       Facebook
# 1988645    110.18.135.0  Hamburg  Hamburg       22587  Chrome       Facebook
# 1522982    110.18.135.0  Hamburg  Hamburg       22587  Chrome       Facebook
# 1108932    110.18.135.0  Hamburg  Hamburg       22587  Chrome       Facebook
# ...                 ...      ...      ...         ...     ...            ...
# 1393079  144.236.17.125  Hamburg  Hamburg       22587  Safari       Facebook
# 1696645  144.236.17.125  Hamburg  Hamburg       22587  Safari       Facebook
# 1505673  144.236.17.125  Hamburg  Hamburg       22587  Safari       Facebook
# 126515   144.236.17.125  Hamburg  Hamburg       22587  Safari       Facebook
# 1066760  144.236.17.125  Hamburg  Hamburg       22587  Safari       Facebook
#
#                                                        uri  event_type
# 778613   /department/men/category/sleep&lounge/brand/ca...  department
# 861029                                      /product/26515     product
# 1988645                                              /cart        cart
# 1522982  /department/men/category/sleep&lounge/brand/ca...  department
# 1108932                                     /product/26515     product
# ...                                                    ...         ...
# 1393079                                              /cart        cart
# 1696645  /department/men/category/outerwear&coats/brand...  department
# 1505673                                     /product/23699     product
# 126515                                               /cart        cart
# 1066760                                          /purchase    purchase
#
# [164 rows x 13 columns]

# %%
# created_at이 문자열이면 datetime으로 변환
events["created_at"] = pd.to_datetime(events["created_at"], utc=True, errors="coerce")

#세션 간 간격(= 발생 시간 간격)
session_duration = (
    events.groupby("session_id")["created_at"]
    .agg(session_start="min", session_end="max")
    .assign(session_duration=lambda x: (x["session_end"] - x["session_start"]).dt.total_seconds() / 60) # 분 단위로 확인
)

session_duration['session_duration'].describe()
# 생각보다 너무 긴데? 무슨 로그아웃하기 전까지 세션 안없어지는건가;;
# Out:
# count    677354.000000
# mean        406.625987
# std        1237.495002
# min           0.000000
# 25%           4.633333
# 50%          17.000000
# 75%          33.000000
# max        5788.716667
# Name: session_duration, dtype: float64

# %%
events['browser'].value_counts()
# Out:
# browser
# Chrome     1218687
# Firefox     487490
# Safari      483743
# IE          121551
# Other       120492
# Name: count, dtype: int64

# %%
events['traffic_source'].value_counts()
# Out:
# traffic_source
# Email       1091988
# Adwords      731144
# Facebook     243834
# YouTube      242938
# Organic      122059
# Name: count, dtype: int64

# %%
events.loc[events['browser'] == 'Chrome', 'traffic_source'].value_counts()
# Out:
# traffic_source
# Email       547261
# Adwords     366399
# YouTube     121863
# Facebook    121437
# Organic      61727
# Name: count, dtype: int64

# %%
events.loc[events['browser'] == 'Other', 'traffic_source'].value_counts()
# Out:
# traffic_source
# Email       54168
# Adwords     36565
# YouTube     12038
# Facebook    11783
# Organic      5938
# Name: count, dtype: int64

# %%
# 아하 페이지 구경한거였구나? 그런 로그 기록이 다 담긴게 이벤트 테이블이군...
events['uri'].value_counts()
# Out:
# uri
# /cart                                                                  595994
# /purchase                                                              181759
# /cancel                                                                125568
# /home                                                                   87712
# /department/women/category/maternity/brand/motherhoodmaternity           3354
#                                                                         ...
# /department/women/category/accessories/brand/allblack                       6
# /department/women/category/fashionhoodies&sweatshirts/brand/citizen         6
# /department/women/category/swim/brand/jamaicanstyle                         6
# /department/men/category/outerwear&coats/brand/toesonthenose                5
# /department/women/category/sweaters/brand/hotfromhollywood                  3
# Name: count, Length: 35530, dtype: int64

# %%
# 
print(f'min: {events['created_at'].min()}')
print(f'max: {events['created_at'].max()}')
# Out:
# min: 2019-01-02 00:05:00+00:00
# max: 2024-01-21 16:18:30+00:00

# %% [markdown]
# ## 3.1 inventory_items

# %%
inventory_items.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490705 entries, 0 to 490704
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              490705 non-null  int64
#  1   product_id                      490705 non-null  int64
#  2   created_at                      490705 non-null  object
#  3   sold_at                         181759 non-null  object
#  4   cost                            490705 non-null  float64
#  5   product_category                490705 non-null  object
#  6   product_name                    490676 non-null  object
#  7   product_brand                   490304 non-null  object
#  8   product_retail_price            490705 non-null  float64
#  9   product_department              490705 non-null  object
#  10  product_sku                     490705 non-null  object
#  11  product_distribution_center_id  490705 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 44.9+ MB

# %%
inventory_items.describe(include='all')
# Out:
#                    id     product_id                 created_at  \
# count   490705.000000  490705.000000                     490705
# unique            NaN            NaN                     463339
# top               NaN            NaN  2020-09-30 15:54:00+00:00
# freq              NaN            NaN                          6
# mean    245353.000000   15254.164465                        NaN
# std     141654.476259    8410.586173                        NaN
# min          1.000000       1.000000                        NaN
# 25%     122677.000000    7984.000000                        NaN
# 50%     245353.000000   15970.000000                        NaN
# 75%     368029.000000   22502.000000                        NaN
# max     490705.000000   29120.000000                        NaN
#
#                           sold_at           cost product_category  \
# count                      181759  490705.000000           490705
# unique                     181526            NaN               26
# top     2023-02-18 01:09:28+00:00            NaN        Intimates
# freq                            2            NaN            36353
# mean                          NaN      28.658986              NaN
# std                           NaN      31.009435              NaN
# min                           NaN       0.008300              NaN
# 25%                           NaN      11.368000              NaN
# 50%                           NaN      19.832000              NaN
# 75%                           NaN      34.550301              NaN
# max                           NaN     557.151002              NaN
#
#                                              product_name product_brand  \
# count                                              490676        490304
# unique                                              27236          2752
# top     Wrangler Men's Premium Performance Cowboy Cut ...     Allegra K
# freq                                                  161         17019
# mean                                                  NaN           NaN
# std                                                   NaN           NaN
# min                                                   NaN           NaN
# 25%                                                   NaN           NaN
# 50%                                                   NaN           NaN
# 75%                                                   NaN           NaN
# max                                                   NaN           NaN
#
#         product_retail_price product_department  \
# count          490705.000000             490705
# unique                   NaN                  2
# top                      NaN              Women
# freq                     NaN             245625
# mean               59.569440                NaN
# std                66.592452                NaN
# min                 0.020000                NaN
# 25%                24.500000                NaN
# 50%                39.990002                NaN
# 75%                69.949997                NaN
# max               999.000000                NaN
#
#                              product_sku  product_distribution_center_id
# count                             490705                   490705.000000
# unique                             29046                             NaN
# top     6B45CF467A9C88001159A826E92C7437                             NaN
# freq                                  58                             NaN
# mean                                 NaN                        5.011514
# std                                  NaN                        2.900016
# min                                  NaN                        1.000000
# 25%                                  NaN                        2.000000
# 50%                                  NaN                        5.000000
# 75%                                  NaN                        8.000000
# max                                  NaN                       10.000000

# %%
inventory_items
# Out:
#             id  product_id                 created_at  \
# 0        67971       13844  2022-07-02 07:09:20+00:00
# 1        67972       13844  2023-12-20 03:28:00+00:00
# 2        67973       13844  2023-06-04 02:53:00+00:00
# 3        72863       13844  2021-10-16 22:58:52+00:00
# 4        72864       13844  2021-08-07 16:33:00+00:00
# ...        ...         ...                        ...
# 490700  311018       25590  2021-12-07 12:47:00+00:00
# 490701  451084       25590  2023-10-10 11:57:57+00:00
# 490702  451085       25590  2020-11-20 05:55:00+00:00
# 490703  486057       25590  2023-02-26 22:35:12+00:00
# 490704  486058       25590  2022-09-12 13:52:00+00:00
#
#                           sold_at      cost product_category  \
# 0       2022-07-24 06:33:20+00:00   2.76804      Accessories
# 1                             NaN   2.76804      Accessories
# 2                             NaN   2.76804      Accessories
# 3       2021-11-22 02:19:52+00:00   2.76804      Accessories
# 4                             NaN   2.76804      Accessories
# ...                           ...       ...              ...
# 490700                        NaN  10.39200        Underwear
# 490701  2023-11-27 11:28:57+00:00  10.39200        Underwear
# 490702                        NaN  10.39200        Underwear
# 490703  2023-04-23 01:24:12+00:00  10.39200        Underwear
# 490704                        NaN  10.39200        Underwear
#
#                              product_name       product_brand  \
# 0                  (ONE) 1 Satin Headband  Funny Girl Designs
# 1                  (ONE) 1 Satin Headband  Funny Girl Designs
# 2                  (ONE) 1 Satin Headband  Funny Girl Designs
# 3                  (ONE) 1 Satin Headband  Funny Girl Designs
# 4                  (ONE) 1 Satin Headband  Funny Girl Designs
# ...                                   ...                 ...
# 490700  ck one Men's Micro Slim Fit Boxer        Calvin Klein
# 490701  ck one Men's Micro Slim Fit Boxer        Calvin Klein
# 490702  ck one Men's Micro Slim Fit Boxer        Calvin Klein
# 490703  ck one Men's Micro Slim Fit Boxer        Calvin Klein
# 490704  ck one Men's Micro Slim Fit Boxer        Calvin Klein
#
#         product_retail_price product_department  \
# 0                       6.99              Women
# 1                       6.99              Women
# 2                       6.99              Women
# 3                       6.99              Women
# 4                       6.99              Women
# ...                      ...                ...
# 490700                 24.00                Men
# 490701                 24.00                Men
# 490702                 24.00                Men
# 490703                 24.00                Men
# 490704                 24.00                Men
#
#                              product_sku  product_distribution_center_id
# 0       2A3E953A5E3D81E67945BCE5519F84C8                               7
# 1       2A3E953A5E3D81E67945BCE5519F84C8                               7
# 2       2A3E953A5E3D81E67945BCE5519F84C8                               7
# 3       2A3E953A5E3D81E67945BCE5519F84C8                               7
# 4       2A3E953A5E3D81E67945BCE5519F84C8                               7
# ...                                  ...                             ...
# 490700  F220707C3AFE39D1779E0A34AF72BB7F                               3
# 490701  F220707C3AFE39D1779E0A34AF72BB7F                               3
# 490702  F220707C3AFE39D1779E0A34AF72BB7F                               3
# 490703  F220707C3AFE39D1779E0A34AF72BB7F                               3
# 490704  F220707C3AFE39D1779E0A34AF72BB7F                               3
#
# [490705 rows x 12 columns]

# %%
print(inventory_items['id'].nunique())
print(inventory_items['product_id'].nunique())
print(inventory_items['product_sku'].nunique())
# Out:
# 490705
# 29046
# 29046

# %%
inventory_items['product_distribution_center_id'].value_counts()
# Out:
# product_distribution_center_id
# 1     65116
# 2     64522
# 3     61218
# 8     50152
# 4     46709
# 9     45577
# 7     45377
# 6     43962
# 5     35803
# 10    32269
# Name: count, dtype: int64

# %%
print(inventory_items['created_at'].min())
print(inventory_items['created_at'].max())
# Out:
# 2018-11-08 04:14:18+00:00
# 2024-01-21 03:29:15.939041+00:00

# %%
print(inventory_items.loc[inventory_items['sold_at'].notnull(), 'sold_at'].min())
print(inventory_items.loc[inventory_items['sold_at'].notnull(), 'sold_at'].max())
# Out:
# 2019-01-06 02:25:41+00:00
# 2024-01-21 18:02:23.533893+00:00

# %%
# datetime 변환
inventory_items["created_at"] = pd.to_datetime(inventory_items["created_at"], utc=True, errors="coerce")
inventory_items["sold_at"] = pd.to_datetime(inventory_items["sold_at"], utc=True, errors="coerce")

# %%
# 재고 머무른 시간(미판매의 경우 비교적 최근 시점_sold_at최대값을 기준으로

# datetime 변환
inventory_items["created_at"] = pd.to_datetime(inventory_items["created_at"], utc=True, errors="coerce")
inventory_items["sold_at"] = pd.to_datetime(inventory_items["sold_at"], utc=True, errors="coerce")

# 기준일: sold_at의 최대값
reference_date = inventory_items["sold_at"].max()

# 판매된 상품 → 판매까지 걸린 기간
inventory_items["days_to_sell"] = (inventory_items["sold_at"] - inventory_items["created_at"]).dt.total_seconds() / 86400

# 미판매 상품 → 현재까지 재고로 남아 있는 기간
inventory_items.loc[inventory_items["sold_at"].isna(), "days_to_sell"] = (
    (reference_date - inventory_items["created_at"]).dt.total_seconds() / 86400
)

inventory_items["days_to_sell"] = inventory_items["days_to_sell"].round(1)

# %%
inventory_items["days_to_sell"].describe()
# Out:
# count    486300.000000
# mean        482.727945
# std         483.101475
# min           0.000000
# 25%          38.675000
# 50%         318.300000
# 75%         901.200000
# max        1480.700000
# Name: days_to_sell, dtype: float64

# %% [markdown]
# ## 3.1 order_items

# %%
order_items.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181759 entries, 0 to 181758
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 181759 non-null  int64
#  1   order_id           181759 non-null  int64
#  2   user_id            181759 non-null  int64
#  3   product_id         181759 non-null  int64
#  4   inventory_item_id  181759 non-null  int64
#  5   status             181759 non-null  object
#  6   created_at         181759 non-null  object
#  7   shipped_at         118281 non-null  object
#  8   delivered_at       63841 non-null   object
#  9   returned_at        18232 non-null   object
#  10  sale_price         181759 non-null  float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 15.3+ MB

# %%
order_items.describe(include='all')
# Out:
#                    id       order_id        user_id     product_id  \
# count   181759.000000  181759.000000  181759.000000  181759.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean     90880.000000   62579.982609   49983.272020   15254.151838
# std      52469.448126   36125.987285   28830.895739    8413.482833
# min          1.000000       1.000000       1.000000       1.000000
# 25%      45440.500000   31266.500000   25031.500000    7979.500000
# 50%      90880.000000   62529.000000   49983.000000   15966.000000
# 75%     136319.500000   93845.500000   74867.500000   22504.000000
# max     181759.000000  125226.000000  100000.000000   29120.000000
#
#         inventory_item_id   status                 created_at  \
# count       181759.000000   181759                     181759
# unique                NaN        5                     181526
# top                   NaN  Shipped  2022-11-08 12:49:10+00:00
# freq                  NaN    54440                          2
# mean        245291.860007      NaN                        NaN
# std         141661.912894      NaN                        NaN
# min              3.000000      NaN                        NaN
# 25%         122565.000000      NaN                        NaN
# 50%         245284.000000      NaN                        NaN
# 75%         367983.000000      NaN                        NaN
# max         490705.000000      NaN                        NaN
#
#                        shipped_at               delivered_at  \
# count                      118281                      63841
# unique                      79123                      43187
# top     2023-12-26 19:56:00+00:00  2023-09-06 16:25:00+00:00
# freq                            9                          9
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#                       returned_at     sale_price
# count                       18232  181759.000000
# unique                      12478            NaN
# top     2023-09-20 00:54:00+00:00            NaN
# freq                            6            NaN
# mean                          NaN      59.568544
# std                           NaN      66.657262
# min                           NaN       0.020000
# 25%                           NaN      24.500000
# 50%                           NaN      39.990002
# 75%                           NaN      69.949997
# max                           NaN     999.000000

# %%
order_items
# Out:
#             id  order_id  user_id  product_id  inventory_item_id     status  \
# 0       152013    104663    83582       14235             410368  Cancelled
# 1        40993     28204    22551       14235             110590   Complete
# 2        51224     35223    28215       14235             138236   Complete
# 3        36717     25278    20165       14235              99072    Shipped
# 4       131061     90241    71954       14235             353798    Shipped
# ...        ...       ...      ...         ...                ...        ...
# 181754    9674      6679     5325       24447              26095   Returned
# 181755    7801      5416     4283       24447              21078    Shipped
# 181756   62986     43364    34691       23546             169937    Shipped
# 181757  106577     73418    58623       24447             287560    Shipped
# 181758  143759     98984    78981       24447             388091    Shipped
#
#                        created_at                 shipped_at  \
# 0       2023-05-07 06:08:40+00:00                        NaN
# 1       2023-03-14 03:47:21+00:00  2023-03-15 22:57:00+00:00
# 2       2023-12-05 13:25:30+00:00  2023-12-06 01:20:00+00:00
# 3       2023-12-22 20:48:19+00:00  2023-12-24 16:44:00+00:00
# 4       2022-06-19 16:57:59+00:00  2022-06-19 19:29:00+00:00
# ...                           ...                        ...
# 181754  2020-12-23 00:05:01+00:00  2020-12-25 22:54:00+00:00
# 181755  2022-01-12 23:51:07+00:00  2022-01-10 03:42:00+00:00
# 181756  2023-02-26 00:38:43+00:00  2023-02-25 06:53:00+00:00
# 181757  2023-11-12 02:41:02+00:00  2023-11-14 20:44:00+00:00
# 181758  2022-03-13 10:29:49+00:00  2022-03-14 01:27:00+00:00
#
#                      delivered_at                returned_at  sale_price
# 0                             NaN                        NaN        0.02
# 1       2023-03-18 01:08:00+00:00                        NaN        0.02
# 2       2023-12-10 10:04:00+00:00                        NaN        0.02
# 3                             NaN                        NaN        0.02
# 4                             NaN                        NaN        0.02
# ...                           ...                        ...         ...
# 181754  2020-12-28 07:08:00+00:00  2020-12-30 22:43:00+00:00      999.00
# 181755                        NaN                        NaN      999.00
# 181756                        NaN                        NaN      999.00
# 181757                        NaN                        NaN      999.00
# 181758                        NaN                        NaN      999.00
#
# [181759 rows x 11 columns]

# %%
print(order_items['id'].nunique())
print(order_items['order_id'].nunique())
print(order_items['user_id'].nunique())
print(order_items['product_id'].nunique())
print(order_items['inventory_item_id'].nunique())
# Out:
# 181759
# 125226
# 80044
# 29046
# 181759

# %%
order_summary = (
    order_items
    .groupby("order_id")
    .agg(
        product_count=("product_id", "nunique"),   # 상품 종류 수
        status_count=("status", "nunique")         # 상태 종류 수
    )
    .reset_index()
)

# %%
order_summary['product_count'].value_counts()
# Out:
# product_count
# 1    87714
# 2    24867
# 4     6369
# 3     6276
# Name: count, dtype: int64

# %%
order_summary['status_count'].value_counts()
# Out:
# status_count
# 1    125226
# Name: count, dtype: int64

# %% [markdown]
# ## 3.1 orders

# %%
events.info(show_counts=True)

# %%
events.describe(include='all')

# %%
events

# %% [markdown]
# ## 3.1 products

# %%
events.info(show_counts=True)

# %%
events.describe(include='all')

# %%
events

# %% [markdown]
# ## 3.1 users

# %%
events.info(show_counts=True)

# %%
events.describe(include='all')

# %%
events

# %% [markdown]
# ## 3.1 events

# %%
events.info(show_counts=True)

# %%
events.describe(include='all')

# %%
events
